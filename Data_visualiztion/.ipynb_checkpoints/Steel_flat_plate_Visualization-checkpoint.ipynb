# %%
import pandas as pd
import numpy as np
import math 
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
SFP= pd.read_excel("Steel-express.xlsx","Steel Flat Plate")

# %%
SFP
# Out:
#           Date  Weeks              type  purchases(kg)  sales(kg)   stock  \
# 0   2023-01-01      1  steel flat plate          50729          0   50729
# 1   2023-01-01      1  steel flat plate          44765          0   95494
# 2   2023-01-01      1  steel flat plate         123671          0  219165
# 3   2023-01-01      1  steel flat plate          53965          0  273130
# 4   2023-01-01      1  steel flat plate          24890          0  298020
# ..         ...    ...               ...            ...        ...     ...
# 603 2023-12-18     51  steel flat plate              0        295   37030
# 604 2023-12-18     51  steel flat plate              0       4900   32130
# 605 2023-12-18     51  steel flat plate              0       4900   27230
# 606 2023-12-18     51  steel flat plate              0       5720   21510
# 607 2023-12-18     51  steel flat plate              0       9130   12380
#
#      price for sales(EGP)  price for purchases(EGP)  Total Sales(EGP)  \
# 0                     NaN                      30.2               0.0
# 1                     NaN                      30.3               0.0
# 2                     NaN                      31.8               0.0
# 3                     NaN                      30.7               0.0
# 4                     NaN                      30.7               0.0
# ..                    ...                       ...               ...
# 603                  39.0                       NaN           11505.0
# 604                  41.3                       NaN          202370.0
# 605                  40.2                       NaN          196980.0
# 606                  42.0                       NaN          240240.0
# 607                  40.4                       NaN          368852.0
#
#      Total Purchases(EGP)  Average price  Average price for sales
# 0               1532015.8      30.200000                36.062648
# 1               1356379.5      30.246877                35.993831
# 2               3932737.8      31.123277                35.938009
# 3               1656725.5      31.039646                35.894924
# 4                764123.0      31.011280                35.845247
# ..                    ...            ...                      ...
# 603                   0.0      33.516548                39.081649
# 604                   0.0      33.516548                39.083695
# 605                   0.0      33.516548                39.084724
# 606                   0.0      33.516548                39.087857
# 607                   0.0      33.516548                39.090103
#
# [608 rows x 12 columns]

# %%
SFP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 608 entries, 0 to 607
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Date                      608 non-null    datetime64[ns]
#  1   Weeks                     608 non-null    int64
#  2   type                      608 non-null    object
#  3   purchases(kg)             608 non-null    int64
#  4   sales(kg)                 608 non-null    int64
#  5   stock                     608 non-null    int64
#  6   price for sales(EGP)      497 non-null    float64
#  7   price for purchases(EGP)  111 non-null    float64
#  8   Total Sales(EGP)          608 non-null    float64
#  9   Total Purchases(EGP)      608 non-null    float64
#  10  Average price             608 non-null    float64
#  11  Average price for sales   608 non-null    float64
# dtypes: datetime64[ns](1), float64(6), int64(4), object(1)
# memory usage: 57.1+ KB

# %%
SFP.isnull().sum()
# Out:
# Date                          0
# Weeks                         0
# type                          0
# purchases(kg)                 0
# sales(kg)                     0
# stock                         0
# price for sales(EGP)        111
# price for purchases(EGP)    497
# Total Sales(EGP)              0
# Total Purchases(EGP)          0
# Average price                 0
# Average price for sales       0
# dtype: int64

# %%
## Filling Mising DATA WITH 0

SFP['price for sales(EGP)'].fillna(0,inplace=True)

SFP['price for purchases(EGP)'].fillna(0,inplace=True)

# %% [markdown]
# ## EDA

# %%
## correlation_matrix to see the correlation between columns
correlation_matrix = SFP.corr().round(1)
sns.set(rc={'figure.figsize':(8,5)})
sns.heatmap(data=correlation_matrix, annot=True);

# %% [markdown]
# ## Data Visualization"

# %%
SFP_PUR = SFP['purchases(kg)']  

plt.hist(SFP_PUR, bins=4, density=True, alpha=0.6, color='b')

plt.show()

# %%
SFP_SALES = SFP['sales(kg)']  


plt.hist(SFP_SALES, bins=4, density=True, alpha=0.6, color='b')

plt.show()

# %%
SFP_stock = SFP['stock']  
plt.hist(SFP_stock, bins=4, density=True, alpha=0.6, color='b')

plt.show()

# %%
# Group by 'type' and calculate the sum of sales  within each group
sum_by_type = round(SFP.groupby('type')['Total Sales(EGP)','Total Purchases(EGP)'].sum())
sum_by_type.plot(kind="bar")
# Out:
# C:\Users\Yousssef Emad\AppData\Local\Temp\ipykernel_26432\1628406726.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   sum_by_type = round(SFP.groupby('type')['Total Sales(EGP)','Total Purchases(EGP)'].sum())
# <AxesSubplot:xlabel='type'>

# %%
sum_by_type = round(SFP.groupby('type')['Average price','Average price for sales'].mean())
sum_by_type.plot(kind="bar")
# Out:
# C:\Users\Yousssef Emad\AppData\Local\Temp\ipykernel_26432\2858037585.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   sum_by_type = round(SFP.groupby('type')['Average price','Average price for sales'].mean())
# <AxesSubplot:xlabel='type'>

# %%
SFP.columns
# Out:
# Index(['Date', 'Weeks', 'type', 'purchases(kg)', 'sales(kg)', 'stock',
#        'price for sales(EGP)', 'price for purchases(EGP)', 'Total Sales(EGP)',
#        'Total Purchases(EGP)', 'Average price', 'Average price for sales'],
#       dtype='object')

# %% [markdown]
# ## Sales_over_Time

# %%
#the best season comes at qtr3 of each year the most selling part of the year 

SFP['Date'] = pd.to_datetime(SFP['Date'])

sales_by_date = SFP.groupby('Date')['Total Purchases(EGP)'].sum().reset_index()


plt.figure(figsize=(10, 6))
plt.plot(sales_by_date['Date'], sales_by_date['Total Purchases(EGP)'])
plt.title('Sales Trends Over Time')
plt.xlabel('Date')
plt.ylabel('Total Purchases(EGP)')
plt.grid(True)
plt.show()

# %%
#the best season comes at qtr3 of each year the most selling part of the year 

SFP['Date'] = pd.to_datetime(SFP['Date'])

sales_by_date = SFP.groupby('Date')['Total Sales(EGP)'].sum().reset_index()


plt.figure(figsize=(10, 6))
plt.plot(sales_by_date['Date'], sales_by_date['Total Sales(EGP)'])
plt.title('Sales Trends Over Time')
plt.xlabel('Date')
plt.ylabel('Total Sales(EGP)')
plt.grid(True)
plt.show()

# %%
#the best season comes at qtr3 of each year the most selling part of the year 

SFP['Date'] = pd.to_datetime(SFP['Date'])

sales_by_date = SFP.groupby('Date')['stock'].sum().reset_index()


plt.figure(figsize=(10, 6))
plt.plot(sales_by_date['Date'], sales_by_date['stock'])
plt.title('Sales Trends Over Time')
plt.xlabel('Date')
plt.ylabel('stock')
plt.grid(True)
plt.show()

# %%
SFP_PV= pd.read_excel("ST-EXPRSS-PV.xlsx","Steel Flat Plate")

# %%
SFP_PV.head(7)
# Out:
#    purchases(kg)  sales(kg)    Stock   Holding  Order_Cost(EGP)  \
# 0        1213656     182557  1031099  364096.8          2709408
# 1              0      41808   989291  309329.7                0
# 2              0      72554   916737  296787.3                0
# 3           2065       5209   913593  275640.6             4610
# 4          28962     139445   803110  282766.5            64656
# 5        1266270     340230  1729150  620814.0          2826865
# 6          52676     193376  1588450  534547.8           117596
#
#     New_Purchase      New_Stock    NEW_HOLDING  NEW_ORDER_COST  \
# 0  346139.316051  163582.316051  103841.794815          772734
# 1       0.000000  121774.316051   49074.694815               0
# 2       0.000000   49220.316051   36532.294815               0
# 3  346139.316051  390150.632102  118607.889631          772734
# 4       0.000000  250705.632102  117045.189631               0
# 5       0.000000  -89524.367898  312349.615423               0
# 6       0.000000 -193376.000000  512226.834042               0
#
#                type  Week
# 0  steel flat plate     1
# 1  steel flat plate     2
# 2  steel flat plate     3
# 3  steel flat plate     4
# 4  steel flat plate     5
# 5  steel flat plate     6
# 6  steel flat plate     7

# %%
# Group by 'type' and calculate the sum of sales  within each group
sum_by_type = round(SFP_PV.groupby('type')['purchases(kg)','New_Purchase'].sum())
sum_by_type.plot(kind="bar")
# Out:
# C:\Users\Yousssef Emad\AppData\Local\Temp\ipykernel_26432\3790076773.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   sum_by_type = round(SFP_PV.groupby('type')['purchases(kg)','New_Purchase'].sum())
# <AxesSubplot:xlabel='type'>

# %%
# Group by 'type' and calculate the sum of sales  within each group
sum_by_type = round(SFP_PV.groupby('type')['Order_Cost(EGP)','NEW_ORDER_COST'].sum())
sum_by_type.plot(kind="bar")
# Out:
# C:\Users\Yousssef Emad\AppData\Local\Temp\ipykernel_26432\2982615617.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   sum_by_type = round(SFP_PV.groupby('type')['Order_Cost(EGP)','NEW_ORDER_COST'].sum())
# <AxesSubplot:xlabel='type'>

# %%
# Group by 'type' and calculate the sum of sales  within each group
sum_by_type = round(SFP_PV.groupby('type')['Holding','NEW_HOLDING'].sum())
sum_by_type.plot(kind="bar")
# Out:
# C:\Users\Yousssef Emad\AppData\Local\Temp\ipykernel_26432\2411790820.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   sum_by_type = round(SFP_PV.groupby('type')['Holding','NEW_HOLDING'].sum())
# <AxesSubplot:xlabel='type'>

# %%
sum_by_type = round(SFP_PV.groupby('type')['Stock','New_Stock'].sum())
sum_by_type.plot(kind="bar")
# Out:
# C:\Users\Yousssef Emad\AppData\Local\Temp\ipykernel_26432\4174711715.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   sum_by_type = round(SFP_PV.groupby('type')['Stock','New_Stock'].sum())
# <AxesSubplot:xlabel='type'>

# %% [markdown]
# ## Time_series

# %%
SFP_PV.columns
# Out:
# Index(['purchases(kg)', 'sales(kg)', 'Stock', 'Holding', 'Order_Cost(EGP)',
#        'New_Purchase', 'New_Stock', 'NEW_HOLDING', 'NEW_ORDER_COST', 'type',
#        'Week'],
#       dtype='object')

# %%
# Group by week and calculate the sum of each column
sales_by_week = SFP_PV.groupby('Week')['Stock', 'New_Stock'].sum().reset_index()

# Columns you want to plot (excluding 'Week' column)
columns_to_plot = list(sales_by_week.columns)
columns_to_plot.remove('Week')

# Plot each column separately
plt.figure(figsize=(10, 6))
for column in columns_to_plot:
    plt.plot(sales_by_week['Week'], sales_by_week[column], label=column)

plt.title('Sales Trends Over Time')
plt.xlabel('Week')
plt.ylabel('Value')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\Yousssef Emad\AppData\Local\Temp\ipykernel_26432\2597855365.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   sales_by_week = SFP_PV.groupby('Week')['Stock', 'New_Stock'].sum().reset_index()

# %%
SFP_PV.columns
# Out:
# Index(['purchases(kg)', 'sales(kg)', 'Stock', 'Holding', 'Order_Cost(EGP)',
#        'New_Purchase', 'New_Stock', 'NEW_HOLDING', 'NEW_ORDER_COST', 'type'],
#       dtype='object')

# %%
# Group by week and calculate the sum of each column
sales_by_week = SFP_PV.groupby('Week')['Holding', 'NEW_HOLDING'].sum().reset_index()

# Columns you want to plot (excluding 'Week' column)
columns_to_plot = list(sales_by_week.columns)
columns_to_plot.remove('Week')

# Plot each column separately
plt.figure(figsize=(10, 6))
for column in columns_to_plot:
    plt.plot(sales_by_week['Week'], sales_by_week[column], label=column)

plt.title('Sales Trends Over Time')
plt.xlabel('Week')
plt.ylabel('Value')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\Yousssef Emad\AppData\Local\Temp\ipykernel_26432\66380283.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   sales_by_week = SFP_PV.groupby('Week')['Holding', 'NEW_HOLDING'].sum().reset_index()

# %%
# Group by week and calculate the sum of each column
sales_by_week = SFP_PV.groupby('Week')['Order_Cost(EGP)', 'NEW_ORDER_COST'].sum().reset_index()

# Columns you want to plot (excluding 'Week' column)
columns_to_plot = list(sales_by_week.columns)
columns_to_plot.remove('Week')

# Plot each column separately
plt.figure(figsize=(10, 6))
for column in columns_to_plot:
    plt.plot(sales_by_week['Week'], sales_by_week[column], label=column)

plt.title('Sales Trends Over Time')
plt.xlabel('Week')
plt.ylabel('Value')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\Yousssef Emad\AppData\Local\Temp\ipykernel_26432\3938867354.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   sales_by_week = SFP_PV.groupby('Week')['Order_Cost(EGP)', 'NEW_ORDER_COST'].sum().reset_index()

# %%
# Group by week and calculate the sum of each column
sales_by_week = SFP_PV.groupby('Week')['purchases(kg)', 'New_Purchase'].sum().reset_index()

# Columns you want to plot (excluding 'Week' column)
columns_to_plot = list(sales_by_week.columns)
columns_to_plot.remove('Week')

# Plot each column separately
plt.figure(figsize=(10, 6))
for column in columns_to_plot:
    plt.plot(sales_by_week['Week'], sales_by_week[column], label=column)

plt.title('Sales Trends Over Time')
plt.xlabel('Week')
plt.ylabel('Value')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\Yousssef Emad\AppData\Local\Temp\ipykernel_26432\2493272346.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   sales_by_week = SFP_PV.groupby('Week')['purchases(kg)', 'New_Purchase'].sum().reset_index()

# %% [markdown]
# ## Box-plots

# %%
sns.boxplot(data=SFP[["sales(kg)"]], orient="h")
plt.show()

# %%
sns.boxplot(data=SFP_PV[["New_Purchase"]], orient="h")
plt.show()

# %%
sns.boxplot(data=SFP_PV[["purchases(kg)"]], orient="h")
plt.show()

# %%
sns.boxplot(data=SFP[["Average price for sales"]], orient="h")
plt.show()
