# %%
import pandas as pd
import numpy as np
import math 
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
SFP= pd.read_excel("Steel-express.xlsx","Steel Flat Plate")

# %%
SFP.head()
# Out:
#         Date  Weeks              type  purchases(kg)  sales(kg)   stock  \
# 0 2023-01-01      1  steel flat plate          50729          0   50729
# 1 2023-01-01      1  steel flat plate          44765          0   95494
# 2 2023-01-01      1  steel flat plate         123671          0  219165
# 3 2023-01-01      1  steel flat plate          53965          0  273130
# 4 2023-01-01      1  steel flat plate          24890          0  298020
#
#    price for sales(EGP)  price for purchases(EGP)  Total Sales(EGP)  \
# 0                   NaN                      30.2               0.0
# 1                   NaN                      30.3               0.0
# 2                   NaN                      31.8               0.0
# 3                   NaN                      30.7               0.0
# 4                   NaN                      30.7               0.0
#
#    Total Purchases(EGP)  Average price  Average price for sales
# 0             1532015.8      30.200000                36.062648
# 1             1356379.5      30.246877                35.993831
# 2             3932737.8      31.123277                35.938009
# 3             1656725.5      31.039646                35.894924
# 4              764123.0      31.011280                35.845247

# %%
SFP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 608 entries, 0 to 607
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Date                      608 non-null    datetime64[ns]
#  1   Weeks                     608 non-null    int64
#  2   type                      608 non-null    object
#  3   purchases(kg)             608 non-null    int64
#  4   sales(kg)                 608 non-null    int64
#  5   stock                     608 non-null    int64
#  6   price for sales(EGP)      497 non-null    float64
#  7   price for purchases(EGP)  111 non-null    float64
#  8   Total Sales(EGP)          608 non-null    float64
#  9   Total Purchases(EGP)      608 non-null    float64
#  10  Average price             608 non-null    float64
#  11  Average price for sales   608 non-null    float64
# dtypes: datetime64[ns](1), float64(6), int64(4), object(1)
# memory usage: 57.1+ KB

# %%
#Avarage_price for purchase and sales

SFP_AVG_PRICE = SFP['Average price'].mean()
SFP_AVG_PRICE
# Out:
# 31.891927748421825

# %%
SFP_AVG_Price_sales =  SFP[SFP['Average price for sales'] > 0]['Average price for sales'].mean()
SFP_AVG_Price_sales
# Out:
# 37.07322725540005

# %% [markdown]
# # Making Pivot Tables

# %%
SFP_PV=SFP.pivot_table(index="Weeks",aggfunc="sum",values=["purchases(kg)","sales(kg)"])

# %%
length = len(SFP_PV)
length
# Out:
# 51

# %% [markdown]
# ## Calculating Stock

# %%
SFP_PV['Stock'] = 0
SFP_PV.iloc[0,2] = SFP_PV.iloc[0,0] - SFP_PV.iloc[0,1]

# %%
SFP_PV.iloc[1:,2] =  (SFP_PV.iloc[1:,0] - SFP_PV.iloc[1:,1])
SFP_PV['Stock'] = SFP_PV['Stock'].cumsum()

# %%
SFP_PV
# Out:
#        purchases(kg)  sales(kg)    Stock
# Weeks
# 1            1213656     182557  1031099
# 2                  0      41808   989291
# 3                  0      72554   916737
# 4               2065       5209   913593
# 5              28962     139445   803110
# 6            1266270     340230  1729150
# 7              52676     193376  1588450
# 8              40927     294033  1335344
# 9                  0     120616  1214728
# 10             98710      76487  1236951
# 11              3525     173671  1066805
# 12                 0      20044  1046761
# 13                 0     109734   937027
# 14                 0      36097   900930
# 15                 0      87616   813314
# 16                 0     193333   619981
# 17                 0      73958   546023
# 18             11782     118353   439452
# 19            139229      26018   552663
# 20             11916      34879   529700
# 21             24477     168288   385889
# 22                 0      18940   366949
# 23              7431       9519   364861
# 24            473831     144934   693758
# 25            703781      30285  1367254
# 26                 0      36875  1330379
# 27            365362      16690  1679051
# 28                 0      70306  1608745
# 29                 0       3895  1604850
# 30                 0        244  1604606
# 31                 0       7576  1597030
# 32             17550      78993  1535587
# 33             48816     180800  1403603
# 34             17591     188521  1232673
# 35             27360      69444  1190589
# 36             30096     242872   977813
# 37             31016     153507   855322
# 38            165795     258451   762666
# 39             23923      87766   698823
# 40             90861      74345   715339
# 41             66024     124770   656593
# 42                 0      95337   561256
# 43                 0      88614   472642
# 44             11869      13214   471297
# 45                 0      98327   372970
# 46             33725     346509    60186
# 47            209316       1050   268452
# 48                 0      77067   191385
# 49             41746     195245    37886
# 50             84280      50336    71830
# 51                 0      59450    12380

# %% [markdown]
# ## Calculating-Holding-cost

# %%
SFP_PV['Holding'] = 0

SFP_PV.iloc[0,3]=SFP_PV.iloc[0,0] * 0.3

for i in range(length-1):
    SFP_PV.iloc[i+1,3] = (SFP_PV.iloc[i,2] + SFP_PV.iloc[i+1,0]) *  0.3

# %%
SFP_PV
# Out:
#        purchases(kg)  sales(kg)    Stock   Holding
# Weeks
# 1            1213656     182557  1031099  364096.8
# 2                  0      41808   989291  309329.7
# 3                  0      72554   916737  296787.3
# 4               2065       5209   913593  275640.6
# 5              28962     139445   803110  282766.5
# 6            1266270     340230  1729150  620814.0
# 7              52676     193376  1588450  534547.8
# 8              40927     294033  1335344  488813.1
# 9                  0     120616  1214728  400603.2
# 10             98710      76487  1236951  394031.4
# 11              3525     173671  1066805  372142.8
# 12                 0      20044  1046761  320041.5
# 13                 0     109734   937027  314028.3
# 14                 0      36097   900930  281108.1
# 15                 0      87616   813314  270279.0
# 16                 0     193333   619981  243994.2
# 17                 0      73958   546023  185994.3
# 18             11782     118353   439452  167341.5
# 19            139229      26018   552663  173604.3
# 20             11916      34879   529700  169373.7
# 21             24477     168288   385889  166253.1
# 22                 0      18940   366949  115766.7
# 23              7431       9519   364861  112314.0
# 24            473831     144934   693758  251607.6
# 25            703781      30285  1367254  419261.7
# 26                 0      36875  1330379  410176.2
# 27            365362      16690  1679051  508722.3
# 28                 0      70306  1608745  503715.3
# 29                 0       3895  1604850  482623.5
# 30                 0        244  1604606  481455.0
# 31                 0       7576  1597030  481381.8
# 32             17550      78993  1535587  484374.0
# 33             48816     180800  1403603  475320.9
# 34             17591     188521  1232673  426358.2
# 35             27360      69444  1190589  378009.9
# 36             30096     242872   977813  366205.5
# 37             31016     153507   855322  302648.7
# 38            165795     258451   762666  306335.1
# 39             23923      87766   698823  235976.7
# 40             90861      74345   715339  236905.2
# 41             66024     124770   656593  234408.9
# 42                 0      95337   561256  196977.9
# 43                 0      88614   472642  168376.8
# 44             11869      13214   471297  145353.3
# 45                 0      98327   372970  141389.1
# 46             33725     346509    60186  122008.5
# 47            209316       1050   268452   80850.6
# 48                 0      77067   191385   80535.6
# 49             41746     195245    37886   69939.3
# 50             84280      50336    71830   36649.8
# 51                 0      59450    12380   21549.0

# %% [markdown]
# ## Calculating order cost

# %%
Order_cost_percnt = 0.07

# %%
SFP_PV['Order_Cost(EGP)'] = 0
SFP_PV.iloc[0:,4] =  round((SFP_PV.iloc[0:,0]*SFP_AVG_PRICE*Order_cost_percnt))

# %% [markdown]
# ## Calculating Avarege Quantity / Oerder

# %%
SFP_AVG_QUN_ORDER =  SFP[SFP['purchases(kg)'] > 0]['purchases(kg)'].mean()
SFP_AVG_QUN_ORDER
# Out:
# 48149.261261261265

# %% [markdown]
# ## EOQ - MODEL

# %%
## FIXED COST FOR PALCING AN ORDER

Fixed_Cost = SFP_AVG_QUN_ORDER*SFP_AVG_PRICE*Order_cost_percnt

# %%
## sum of annual sales
Sum_sales = SFP_PV['sales(kg)'].sum()
Sum_sales
# Out:
# 5332188

# %%
## carring cost 
Carry_cost  = 0.3

# %%
## average price per kg
Price = SFP_AVG_PRICE 
Price
# Out:
# 31.891927748421825

# %%
SFP_EOQ = math.sqrt((2*Fixed_Cost*Sum_sales)/(Carry_cost*Price))
SFP_EOQ
# Out:
# 346139.31605093495

# %%
## lead time 

Sum_sales / SFP_EOQ
# Out:
# 15.40474529398839

# %% [markdown]
# ## Reorder-point

# %%
Lead_time = 3

Weakly_average_usage = Sum_sales / length

# %%
Re_order_point = Lead_time * Weakly_average_usage
Re_order_point
# Out:
# 313658.1176470588

# %%
SFP_PV
# Out:
#        purchases(kg)  sales(kg)    Stock   Holding  Order_Cost(EGP)
# Weeks
# 1            1213656     182557  1031099  364096.8        2709408.0
# 2                  0      41808   989291  309329.7              0.0
# 3                  0      72554   916737  296787.3              0.0
# 4               2065       5209   913593  275640.6           4610.0
# 5              28962     139445   803110  282766.5          64656.0
# 6            1266270     340230  1729150  620814.0        2826865.0
# 7              52676     193376  1588450  534547.8         117596.0
# 8              40927     294033  1335344  488813.1          91367.0
# 9                  0     120616  1214728  400603.2              0.0
# 10             98710      76487  1236951  394031.4         220364.0
# 11              3525     173671  1066805  372142.8           7869.0
# 12                 0      20044  1046761  320041.5              0.0
# 13                 0     109734   937027  314028.3              0.0
# 14                 0      36097   900930  281108.1              0.0
# 15                 0      87616   813314  270279.0              0.0
# 16                 0     193333   619981  243994.2              0.0
# 17                 0      73958   546023  185994.3              0.0
# 18             11782     118353   439452  167341.5          26303.0
# 19            139229      26018   552663  173604.3         310820.0
# 20             11916      34879   529700  169373.7          26602.0
# 21             24477     168288   385889  166253.1          54643.0
# 22                 0      18940   366949  115766.7              0.0
# 23              7431       9519   364861  112314.0          16589.0
# 24            473831     144934   693758  251607.6        1057797.0
# 25            703781      30285  1367254  419261.7        1571145.0
# 26                 0      36875  1330379  410176.2              0.0
# 27            365362      16690  1679051  508722.3         815647.0
# 28                 0      70306  1608745  503715.3              0.0
# 29                 0       3895  1604850  482623.5              0.0
# 30                 0        244  1604606  481455.0              0.0
# 31                 0       7576  1597030  481381.8              0.0
# 32             17550      78993  1535587  484374.0          39179.0
# 33             48816     180800  1403603  475320.9         108979.0
# 34             17591     188521  1232673  426358.2          39271.0
# 35             27360      69444  1190589  378009.9          61079.0
# 36             30096     242872   977813  366205.5          67187.0
# 37             31016     153507   855322  302648.7          69241.0
# 38            165795     258451   762666  306335.1         370127.0
# 39             23923      87766   698823  235976.7          53407.0
# 40             90861      74345   715339  236905.2         202841.0
# 41             66024     124770   656593  234408.9         147394.0
# 42                 0      95337   561256  196977.9              0.0
# 43                 0      88614   472642  168376.8              0.0
# 44             11869      13214   471297  145353.3          26497.0
# 45                 0      98327   372970  141389.1              0.0
# 46             33725     346509    60186  122008.5          75289.0
# 47            209316       1050   268452   80850.6         467284.0
# 48                 0      77067   191385   80535.6              0.0
# 49             41746     195245    37886   69939.3          93195.0
# 50             84280      50336    71830   36649.8         188150.0
# 51                 0      59450    12380   21549.0              0.0

# %% [markdown]
# ## New stock

# %%
SFP_new_pur = np.zeros(length)
SFP_new_stock = np.zeros(length)
LD = 0
SFP_new_pur[0] = SFP_EOQ
SFP_new_stock[0] = SFP_new_pur[0] - SFP_PV.iloc[0,1]

# %%
for i in range(length-1):
    if(SFP_new_stock[i]  <= Re_order_point):
            if(SFP_new_stock[i] > 0):
                SFP_new_stock[i+1] = SFP_new_stock[i] + (SFP_new_pur[i+1] - SFP_PV.iloc[i+1,1])
                LD = LD - 1
            else:
                SFP_new_stock[i+1] = 0 + (SFP_new_pur[i+1] - SFP_PV.iloc[i+1,1])
                LD = LD - 1
            if(LD<=0 and i < length-4):
                SFP_new_pur[i+3] = SFP_EOQ
                LD=3
    else: 
        if(SFP_new_stock[i] > 0):
                SFP_new_stock[i+1] = SFP_new_stock[i] + (SFP_new_pur[i+1] - SFP_PV.iloc[i+1,1])
                LD = LD - 1
        else:
            SFP_new_stock[i+1] = 0 + (SFP_new_pur[i+1] - SFP_PV_copy.iloc[i+1,1])
            LD = LD - 1

# %%
SFP_PV['New_Purchase'] = SFP_new_pur
SFP_PV['New_Stock'] = SFP_new_stock

# %%
SFP_PV
# Out:
#        purchases(kg)  sales(kg)    Stock   Holding  Order_Cost(EGP)  \
# Weeks
# 1            1213656     182557  1031099  364096.8        2709408.0
# 2                  0      41808   989291  309329.7              0.0
# 3                  0      72554   916737  296787.3              0.0
# 4               2065       5209   913593  275640.6           4610.0
# 5              28962     139445   803110  282766.5          64656.0
# 6            1266270     340230  1729150  620814.0        2826865.0
# 7              52676     193376  1588450  534547.8         117596.0
# 8              40927     294033  1335344  488813.1          91367.0
# 9                  0     120616  1214728  400603.2              0.0
# 10             98710      76487  1236951  394031.4         220364.0
# 21     346139.316051  344740.632102  101515.784446             0.0
# 22          0.000000  325800.632102   51029.384446             0.0
# 23          0.000000  316281.632102   45347.384446             0.0
# 24          0.000000  171347.632102  146333.479261        772734.0
# 25          0.000000  141062.632102  102853.279261             0.0
# 26          0.000000  104187.632102   93767.779261             0.0
# 27     346139.316051  433636.948153   82705.279261             0.0
# 28          0.000000  363330.948153  181540.074076        772734.0
# 29          0.000000  359435.948153  160448.274076             0.0
# 30          0.000000  359191.948153  159279.774076             0.0
# 31          0.000000  351615.948153  159206.574076             0.0
# 32          0.000000  272622.948153  156933.774076             0.0
# 33          0.000000   91822.948153  133235.874076             0.0
# 34          0.000000  -96698.051847   78995.874076             0.0
# 35     346139.316051  276695.316051   22439.574076             0.0
# 36          0.000000   33823.316051  105448.168892        772734.0
# 37          0.000000 -119683.683949  151481.129546             0.0
# 38     346139.316051   87688.316051  684601.695583             0.0
# 39          0.000000     -77.683949  103841.794815        772734.0
# 40          0.000000  -74345.000000   77511.994815             0.0
# 41     346139.316051  221369.316051   55208.494815             0.0
# 42          0.000000  126032.316051  121619.289631        772734.0
# 43          0.000000   37418.316051   93018.189631             0.0
# 44     346139.316051  370343.632102   66433.989631             0.0
# 45          0.000000  272016.632102  166311.584446        772734.0
# 46          0.000000  -74492.367898  136813.484446             0.0
# 47          0.000000   -1050.000000   32860.784446             0.0
# 48     346139.316051  269072.316051   32545.784446             0.0
# 49          0.000000   73827.316051  113267.479261        772734.0
# 50          0.000000   23491.316051   54693.979261             0.0
# 51          0.000000  -35958.683949   39593.179261             0.0

# %% [markdown]
# ### New Holding   and Shortage

# %%
Shortage = SFP_AVG_Price_sales-SFP_AVG_PRICE-Carry_cost-SFP_AVG_PRICE*Order_cost_percnt
Shortage
# Out:
# 2.6488645645886963

# %%
SFP_PV['NEW_HOLDING'] = 0

SFP_PV.iloc[0,7]=SFP_PV.iloc[0,5] * 0.3

for i in range(length-1):
    if(SFP_PV.iloc[i,6] > 0 and SFP_PV.iloc[i+1,6] > 0 ):
            SFP_PV.iloc[i+1,7] = (SFP_PV.iloc[i,6] + SFP_PV.iloc[i+1,5]) * Carry_cost
    
    elif(SFP_PV.iloc[i,6] <= 0 and SFP_PV.iloc[i+1,6] > 0):
             SFP_PV.iloc[i+1,7] = SFP_PV.iloc[i+1,5] * Carry_cost
    
    elif(SFP_PV.iloc[i,6] > 0 and SFP_PV.iloc[i+1,6] <= 0 ):
            SFP_PV.iloc[i+1,7] = ((SFP_PV.iloc[i,6] + SFP_PV.iloc[i+1,5]) * Carry_cost) + (SFP_PV.iloc[i+1,6]*(-Shortage))        
    
    elif(SFP_PV.iloc[i,6] < 0 and SFP_PV.iloc[i+1,6] <= 0 ):
            SFP_PV.iloc[i+1,7] = ((SFP_PV.iloc[i+1,5]) * Carry_cost)+(SFP_PV.iloc[i+1,6]*-Shortage)

# %% [markdown]
# ### NEW Order_cost

# %%
SFP_PV['NEW_ORDER_COST'] = 0

SFP_PV.iloc[0:,8] = round((SFP_PV.iloc[0:,5]*SFP_AVG_PRICE*Order_cost_percnt))

# %%
SFP_PV
# Out:
#        purchases(kg)  sales(kg)    Stock   Holding  Order_Cost(EGP)  \
# Weeks
# 1            1213656     182557  1031099  364096.8        2709408.0
# 2                  0      41808   989291  309329.7              0.0
# 3                  0      72554   916737  296787.3              0.0
# 4               2065       5209   913593  275640.6           4610.0
# 5              28962     139445   803110  282766.5          64656.0
# 6            1266270     340230  1729150  620814.0        2826865.0
# 7              52676     193376  1588450  534547.8         117596.0
# 8              40927     294033  1335344  488813.1          91367.0
# 9                  0     120616  1214728  400603.2              0.0
# 10             98710      76487  1236951  394031.4         220364.0
# 11              3525     173671  1066805  372142.8           7869.0
# 12                 0      20044  1046761  320041.5              0.0
# 13                 0     109734   937027  314028.3              0.0
# 14                 0      36097   900930  281108.1              0.0
# 15                 0      87616   813314  270279.0              0.0
# 16                 0     193333   619981  243994.2              0.0
# 17                 0      73958   546023  185994.3              0.0
# 18             11782     118353   439452  167341.5          26303.0
# 19            139229      26018   552663  173604.3         310820.0
# 20             11916      34879   529700  169373.7          26602.0
# 21             24477     168288   385889  166253.1          54643.0
# 22                 0      18940   366949  115766.7              0.0
# 23              7431       9519   364861  112314.0          16589.0
# 24            473831     144934   693758  251607.6        1057797.0
# 25            703781      30285  1367254  419261.7        1571145.0
# 26                 0      36875  1330379  410176.2              0.0
# 27            365362      16690  1679051  508722.3         815647.0
# 28                 0      70306  1608745  503715.3              0.0
# 29                 0       3895  1604850  482623.5              0.0
# 30                 0        244  1604606  481455.0              0.0
# 31                 0       7576  1597030  481381.8              0.0
# 32             17550      78993  1535587  484374.0          39179.0
# 33             48816     180800  1403603  475320.9         108979.0
# 34             17591     188521  1232673  426358.2          39271.0
# 35             27360      69444  1190589  378009.9          61079.0
# 36             30096     242872   977813  366205.5          67187.0
# 37             31016     153507   855322  302648.7          69241.0
# 38            165795     258451   762666  306335.1         370127.0
# 39             23923      87766   698823  235976.7          53407.0
# 40             90861      74345   715339  236905.2         202841.0
# 41             66024     124770   656593  234408.9         147394.0
# 42                 0      95337   561256  196977.9              0.0
# 43                 0      88614   472642  168376.8              0.0
# 44             11869      13214   471297  145353.3          26497.0
# 45                 0      98327   372970  141389.1              0.0
# 46             33725     346509    60186  122008.5          75289.0
# 47            209316       1050   268452   80850.6         467284.0
# 48                 0      77067   191385   80535.6              0.0
# 49             41746     195245    37886   69939.3          93195.0
# 50             84280      50336    71830   36649.8         188150.0
# 51                 0      59450    12380   21549.0              0.0
#
#         New_Purchase      New_Stock    NEW_HOLDING  NEW_ORDER_COST
# Weeks
# 1      346139.316051  163582.316051  103841.794815        772734.0
# 2           0.000000  121774.316051   49074.694815             0.0
# 3           0.000000   49220.316051   36532.294815             0.0
# 4      346139.316051  390150.632102  118607.889631        772734.0
